# %% [markdown]
# <h1>Hands-on Lab : Web Scraping</h1>

# %% [markdown]
# <h2>Extraer información del sitio web indicado</h2>
# <p>Extraerás los datos del siguiente sitio web:</p>

# %%
# asignando la url a una variable
url = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/labs/datasets/Programming_Languages.html"

# %% [markdown]
# <p>Los datos que necesitas extraer son el nombre del lenguaje de programación y el salario medio anual. Es una buena idea abrir la URL en tu navegador web y estudiar el contenido de la página web antes de empezar a extraer datos.</p>

# %%
# importando laslibrerias necesarias
from bs4 import BeautifulSoup # Este modulo ayuda con el web scrapping.
import requests  # Este modulo ayuda para descargar la webpage
import pandas as pd

# %%
# Descargando la webpage de la url
data  = requests.get(url).text

# %%
# creando un objeto soup
soup = BeautifulSoup(data,"html.parser")

# %%
# Scrape el Lenguaje de programacion y  promedio anual de salario
#Encontrando la tabla html en la web page
table = soup.find('table') # En html la tabla es representado por la etiqueta<table>

# %%
# Obteniendo todas las filas de la tabla
for row in table.find_all('tr'): # En html table fila es representado por la etiqueta <tr>
    # Obteniendo todas las columnas en cada fila.
    cols = row.find_all('td') # in html a column is represented by the tag <td>
    language = cols[1].getText() # store the value in column 3 as color_name
    creator = cols[2].getText() # store the value in column 4 as color_code
    annual_salary = cols[3].getText() # store the value in column 4 as color_code
    difficult = cols[4].getText() # store the value in column 4 as color_code
    print("{}--->{}---->{}--->{}".format(language, creator, annual_salary, difficult))
# Out:
# Language--->Created By---->Average Annual Salary--->Learning Difficulty
# Python--->Guido van Rossum---->$114,383--->Easy
# Java--->James Gosling---->$101,013--->Easy
# R--->Robert Gentleman, Ross Ihaka---->$92,037--->Hard
# Javascript--->Netscape---->$110,981--->Easy
# Swift--->Apple---->$130,801--->Easy
# C++--->Bjarne Stroustrup---->$113,865--->Hard
# C#--->Microsoft---->$88,726--->Hard
# PHP--->Rasmus Lerdorf---->$84,727--->Easy
# SQL--->Donald D. Chamberlin, Raymond F. Boyce.---->$84,793--->Easy
# Go--->Robert Griesemer, Ken Thompson, Rob Pike.---->$94,082--->Difficult

# %%
# convirtiendo la taba html a un dataframe de pandas
df = pd.read_html(str(table))[0]
# Out:
# <ipython-input-11-3c54dff03927>:2: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]

# %%
#generando encabezados a la tabla
#header =["#","Languages","Creted by","Average Annual Salary","Learning Difficulty"]
# aplicando los encabezados al dataframe
#df.columns = header
df
# Out:
#       #   Languages                                  Creted by  \
# 0   No.    Language                                 Created By
# 1     1      Python                           Guido van Rossum
# 2     2        Java                              James Gosling
# 3     3           R               Robert Gentleman, Ross Ihaka
# 4     4  Javascript                                   Netscape
# 5     5       Swift                                      Apple
# 6     6         C++                          Bjarne Stroustrup
# 7     7          C#                                  Microsoft
# 8     8         PHP                             Rasmus Lerdorf
# 9     9         SQL    Donald D. Chamberlin, Raymond F. Boyce.
# 10   10          Go  Robert Griesemer, Ken Thompson, Rob Pike.
#
#     Average Annual Salary  Learning Difficulty
# 0   Average Annual Salary  Learning Difficulty
# 1                $114,383                 Easy
# 2                $101,013                 Easy
# ...

# %%
#Save the scrapped data into a file named popular-languages.csv
df.to_csv("popular-languages")
